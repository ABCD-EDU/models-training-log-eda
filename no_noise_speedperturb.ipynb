# %%
import matplotlib.pyplot as plt

# epoch data
epochs = [i for i in range(1, 30)]

# learning rate data
lrs = [1.5e-4]*26 + [7.5e-5]*3

# train si-snr data
train_sisnr = [-1.78e-01, -1.16e+00, -1.71e+00, -2.15e+00, -2.47e+00,
               -2.62e+00, -2.89e+00, -3.01e+00, -3.26e+00, -3.42e+00,
               -3.61e+00, -3.83e+00, -3.90e+00, -3.98e+00, -4.03e+00,
               -4.13e+00, -4.23e+00, -4.30e+00, -4.30e+00, -4.51e+00,
               -4.48e+00, -4.50e+00, -4.64e+00, -4.61e+00, -4.78e+00,
               -4.77e+00, -5.16e+00, -5.31e+00, -5.38e+00]

# validation si-snr data
valid_sisnr = [-1.12e+00, -1.38e+00, -1.99e+00, -2.35e+00, -1.99e+00,
               -2.80e+00, -2.82e+00, -3.12e+00, -3.79e+00, -3.88e+00,
               -3.86e+00, -3.91e+00, -4.01e+00, -4.46e+00, -4.31e+00,
               -4.35e+00, -4.73e+00, -4.86e+00, -4.59e+00, -5.04e+00,
               -4.85e+00, -4.76e+00, -5.06e+00, -4.99e+00, -5.05e+00,
               -4.89e+00, -5.54e+00, -5.58e+00, -5.53e+00]

# plot the train and validation si-snr vs epoch
fig, ax = plt.subplots(figsize=(20, 13))
ax.plot(epochs, train_sisnr, label='Train SI-SNR')
ax.plot(epochs, valid_sisnr, label='Validation SI-SNR')

# add labels and title
ax.set_xlabel('Epochs')
ax.set_ylabel('SI-SNR')
ax.set_title('Train and Validation SI-SNR vs Epochs')

# add legend
ax.legend()

# plot the learning rate vs epoch
fig, ax = plt.subplots(figsize=(20, 13))
ax.plot(epochs, lrs)

# add labels and title
ax.set_xlabel('Epochs')
ax.set_ylabel('Learning Rate')
ax.set_title('Learning Rate vs Epochs')

# show the plots
plt.show()
